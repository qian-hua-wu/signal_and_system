# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot
import numpy as np

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %% [markdown]
# ### Exercise 1
#
# Run and listen to the examples in chap03.ipynb, which is in the repository for this book, and also available at http://tinyurl.com/thinkdsp03. In the leakage example, try replacing the Hamming window with one of the other windows provided by NumPy, and see what effect they have on leakage. See http://docs.scipy.org/doc/numpy/reference/routines.window.html
#
# 運行並收聽chap03.ipynb中的示例，該示例位於本書的存儲庫中，也可從http://tinyurl.com/thinkdsp03獲得。 在洩漏示例中，嘗試用NumPy提供的其他窗口之一替換Hamming窗口，並查看它們對洩漏有什麼影響。 參見http://docs.scipy.org/doc/numpy/reference/routines.window.html

# %%
signal = thinkdsp.SinSignal(freq=440)
duration = signal.period * 30.25
wave = signal.make_wave(duration)
spectrum = wave.make_spectrum()

spectrum.plot(high=880)
thinkplot.config(xlabel='Frequency (Hz)')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# The following figure shows the effect of 4 different windows.
#
# 下圖顯示了4個不同窗口的效果。

# %%
thinkplot.preplot(4)

for window_func in [np.bartlett, np.blackman, np.hamming, np.hanning]:
    wave = signal.make_wave(duration)
    wave.ys *= window_func(len(wave.ys))

    spectrum = wave.make_spectrum()
    spectrum.plot(high=880, label=window_func.__name__)

thinkplot.config(xlabel='Frequency (Hz)', legend=True)

# %% [markdown]
# All four do a good job of reducing leakage. The Bartlett filter leaves some residual "ringing". The Hamming filter dissipates the least amount of energy.
#
# 所有這四個都很好地減少了洩漏。 Bartlett過濾器留下一些殘留的“振鈴”。 漢明濾波器消耗的能量最少。
